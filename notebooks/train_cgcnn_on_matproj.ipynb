# %%
import datetime
import os
import sys
import yaml

import torch

# %%
# TODO list:
# 
# [x] load config, make it editable
# [ ] set up matplotlib-friendly logger
# [x] load task
# [x] load model
# [x] load criterion
# [x] load optimizer
# [x] load extras like scheduler, etc.
# [x] train model
# [ ] plot loss curves

# %%
ROOT_DIR = "../" # path to the base of the repository.
sys.path.insert(0, ROOT_DIR)

# %% [markdown]
# ## Load base config, set parameters, create directories

# %%
base_config_yaml = os.path.join(ROOT_DIR, "configs/xie_grossman_mat_proj/cgcnn.yml")
config = yaml.safe_load(open(base_config_yaml, "r"))

includes = config.get("includes", [])
for include in includes:
    include_config = yaml.safe_load(open(os.path.join(ROOT_DIR, include), "r"))
    config.update(include_config)

config.pop("includes")
# Out:
# ['configs/xie_grossman_mat_proj/base.yml']

# %%
timestamp = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")

# Specify which configuration parameters to override.
config_override = {
    "optim": {
        "batch_size": 64,
        "lr_initial": 0.001,
        "max_epochs": 50,
        "lr_milestones": [100, 150],
        "lr_gamma": 0.1,
        "warmup_epochs": 10,
        "warmup_factor": 0.2
    },
    "dataset": {
        "src": "../data/data/xie_grossman_mat_proj",
        "train_size": 28000,
        "val_size": 2900,
        "test_size": 3000,
    },
    # the following parameters are necessary.
    "cmd": {
        "seed": 1,
        "checkpoint_dir": os.path.join(ROOT_DIR, "checkpoints", timestamp),
        "results_dir": os.path.join(ROOT_DIR, "results", timestamp),
        "logs_dir": os.path.join(ROOT_DIR, "logs", config["logger"], timestamp),
        "print_every": 100,
    }
}

# Update config.
config.update(config_override)

# Create directories.
os.makedirs(os.path.join(ROOT_DIR, "checkpoints", timestamp))
os.makedirs(os.path.join(ROOT_DIR, "results", timestamp))
os.makedirs(os.path.join(ROOT_DIR, "logs", config["logger"], timestamp))

# Print overall config.
print(yaml.dump(config, default_flow_style=False))
# Out:
# cmd:
#   checkpoint_dir: ../checkpoints/2020-03-16-00-23-43
#   logs_dir: ../logs/wandb/2020-03-16-00-23-43
#   print_every: 100
#   results_dir: ../results/2020-03-16-00-23-43
#   seed: 1
# dataset:
#   src: ../data/data/xie_grossman_mat_proj
#   test_size: 3000
#   train_size: 28000
#   val_size: 2900
# logger: wandb
# model: cgcnn
# model_attributes:
#   atom_embedding_size: 64
#   fc_feat_size: 128
#   num_fc_layers: 4
#   num_graph_conv_layers: 6
# optim:
#   batch_size: 64
#   lr_gamma: 0.1
#   lr_initial: 0.001
#   lr_milestones:
#   - 100
#   - 150
#   max_epochs: 50
#   warmup_epochs: 10
#   warmup_factor: 0.2
# task:
#   dataset: xie_grossman_mat_proj
#   description: Formation energy per atom regression on the Materials Project dataset
#     from Xie and Grossman.
#   labels:
#   - formation energy per atom
#   metric: mae
#   type: regression

# %% [markdown]
# ## Load task, dataset, model, criterion, optimizer

# %%
from ocpmodels.trainers import BaseTrainer

trainer = BaseTrainer(args=None)

trainer.config = config
trainer.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trainer.is_debug = False
trainer.is_vis = False
trainer.logger = None
trainer.load_seed_from_config()

# %%
trainer.load_task()
trainer.load_model()
trainer.load_criterion()
trainer.load_optimizer()
trainer.load_extras()
# Out:
# ### Loading dataset: xie_grossman_mat_proj
# ### Loading model: cgcnn
# ### Loaded CGCNN with 196801 parameters.

# %%
print(trainer.model)
# Out:
# CGCNN(
#   (embedding): Linear(in_features=92, out_features=64, bias=True)
#   (convs): ModuleList(
#     (0): CGCNNConv(
#       (fc_pre): Sequential(
#         (0): Linear(in_features=169, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (fc_post): Sequential(
#         (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): CGCNNConv(
#       (fc_pre): Sequential(
#         (0): Linear(in_features=169, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (fc_post): Sequential(
#         (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): CGCNNConv(
#       (fc_pre): Sequential(
#         (0): Linear(in_features=169, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (fc_post): Sequential(
#         (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): CGCNNConv(
#       (fc_pre): Sequential(
#         (0): Linear(in_features=169, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (fc_post): Sequential(
#         (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): CGCNNConv(
#       (fc_pre): Sequential(
#         (0): Linear(in_features=169, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (fc_post): Sequential(
#         (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): CGCNNConv(
#       (fc_pre): Sequential(
#         (0): Linear(in_features=169, out_features=128, bias=True)
#         (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (fc_post): Sequential(
#         (0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv_to_fc): Sequential(
#     (0): Linear(in_features=64, out_features=128, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#   )
#   (fcs): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): Softplus(beta=1, threshold=20)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): Softplus(beta=1, threshold=20)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): Softplus(beta=1, threshold=20)
#   )
#   (fc_out): Linear(in_features=128, out_features=1, bias=True)
# )

# %% [markdown]
# ## Train

# %%
trainer.train()
# Out:
# epoch: 0.0023, loss: 0.8411, formation energy per atom/mae: 0.9031
# epoch: 0.2306, loss: 0.4904, formation energy per atom/mae: 0.5265
# epoch: 0.4589, loss: 0.3692, formation energy per atom/mae: 0.3964
# epoch: 0.6872, loss: 0.3193, formation energy per atom/mae: 0.3428
# epoch: 0.9155, loss: 0.2897, formation energy per atom/mae: 0.3111
# ### Evaluating on val.
# loss: 0.2184, formation energy per atom/mae: 0.2345
# ### Evaluating on test.
# loss: 0.2166, formation energy per atom/mae: 0.2325
# epoch: 1.0023, loss: 0.2816, formation energy per atom/mae: 0.3024
# epoch: 1.2306, loss: 0.2661, formation energy per atom/mae: 0.2857
# epoch: 1.4589, loss: 0.2553, formation energy per atom/mae: 0.2741
# epoch: 1.6872, loss: 0.2469, formation energy per atom/mae: 0.2651
# epoch: 1.9155, loss: 0.2391, formation energy per atom/mae: 0.2567
# ### Evaluating on val.
# loss: 0.1230, formation energy per atom/mae: 0.1321
# ### Evaluating on test.
# loss: 0.1204, formation energy per atom/mae: 0.1293
# epoch: 2.0023, loss: 0.2365, formation energy per atom/mae: 0.2540
# epoch: 2.2306, loss: 0.2328, formation energy per atom/mae: 0.2500
# epoch: 2.4589, loss: 0.2281, formation energy per atom/mae: 0.2450
# epoch: 2.6872, loss: 0.2245, formation energy per atom/mae: 0.2411
# epoch: 2.9155, loss: 0.2210, formation energy per atom/mae: 0.2372
# ### Evaluating on val.
# loss: 0.1355, formation energy per atom/mae: 0.1455
# ### Evaluating on test.
# loss: 0.1332, formation energy per atom/mae: 0.1430
# epoch: 3.0023, loss: 0.2192, formation energy per atom/mae: 0.2354
# epoch: 3.2306, loss: 0.2156, formation energy per atom/mae: 0.2315
# epoch: 3.4589, loss: 0.2127, formation energy per atom/mae: 0.2284
# epoch: 3.6872, loss: 0.2101, formation energy per atom/mae: 0.2256
# epoch: 3.9155, loss: 0.2069, formation energy per atom/mae: 0.2221
# ### Evaluating on val.
# loss: 0.1256, formation energy per atom/mae: 0.1349
# ### Evaluating on test.
# loss: 0.1241, formation energy per atom/mae: 0.1333
# epoch: 4.0023, loss: 0.2060, formation energy per atom/mae: 0.2212
# epoch: 4.2306, loss: 0.2035, formation energy per atom/mae: 0.2185
# epoch: 4.4589, loss: 0.2014, formation energy per atom/mae: 0.2163
# epoch: 4.6872, loss: 0.1992, formation energy per atom/mae: 0.2138
# epoch: 4.9155, loss: 0.1964, formation energy per atom/mae: 0.2109
# ### Evaluating on val.
# loss: 0.1988, formation energy per atom/mae: 0.2135
# ### Evaluating on test.
# loss: 0.1970, formation energy per atom/mae: 0.2116
# epoch: 5.0023, loss: 0.1959, formation energy per atom/mae: 0.2103
# epoch: 5.2306, loss: 0.1934, formation energy per atom/mae: 0.2077
# epoch: 5.4589, loss: 0.1911, formation energy per atom/mae: 0.2052
# epoch: 5.6872, loss: 0.1892, formation energy per atom/mae: 0.2032
# epoch: 5.9155, loss: 0.1877, formation energy per atom/mae: 0.2015
# ### Evaluating on val.
# loss: 0.1145, formation energy per atom/mae: 0.1229
# ### Evaluating on test.
# loss: 0.1086, formation energy per atom/mae: 0.1166
# epoch: 6.0023, loss: 0.1870, formation energy per atom/mae: 0.2007
# epoch: 6.2306, loss: 0.1856, formation energy per atom/mae: 0.1993
# epoch: 6.4589, loss: 0.1841, formation energy per atom/mae: 0.1977
# epoch: 6.6872, loss: 0.1826, formation energy per atom/mae: 0.1961
# epoch: 6.9155, loss: 0.1810, formation energy per atom/mae: 0.1943
# ### Evaluating on val.
# loss: 0.0952, formation energy per atom/mae: 0.1022
# ### Evaluating on test.
# loss: 0.0948, formation energy per atom/mae: 0.1017
# epoch: 7.0023, loss: 0.1804, formation energy per atom/mae: 0.1937
# epoch: 7.2306, loss: 0.1788, formation energy per atom/mae: 0.1920
# epoch: 7.4589, loss: 0.1773, formation energy per atom/mae: 0.1904
# epoch: 7.6872, loss: 0.1758, formation energy per atom/mae: 0.1888
# epoch: 7.9155, loss: 0.1746, formation energy per atom/mae: 0.1875
# ### Evaluating on val.
# loss: 0.1127, formation energy per atom/mae: 0.1210
# ### Evaluating on test.
# loss: 0.1073, formation energy per atom/mae: 0.1152
# epoch: 8.0023, loss: 0.1741, formation energy per atom/mae: 0.1869
# epoch: 8.2306, loss: 0.1727, formation energy per atom/mae: 0.1854
# epoch: 8.4589, loss: 0.1717, formation energy per atom/mae: 0.1843
# epoch: 8.6872, loss: 0.1706, formation energy per atom/mae: 0.1832
# epoch: 8.9155, loss: 0.1693, formation energy per atom/mae: 0.1818
# ### Evaluating on val.
# loss: 0.1457, formation energy per atom/mae: 0.1564
# ### Evaluating on test.
# loss: 0.1441, formation energy per atom/mae: 0.1547
# epoch: 9.0023, loss: 0.1689, formation energy per atom/mae: 0.1814
# epoch: 9.2306, loss: 0.1680, formation energy per atom/mae: 0.1804
# epoch: 9.4589, loss: 0.1669, formation energy per atom/mae: 0.1792
# epoch: 9.6872, loss: 0.1656, formation energy per atom/mae: 0.1779
# epoch: 9.9155, loss: 0.1648, formation energy per atom/mae: 0.1769
# ### Evaluating on val.
# loss: 0.1204, formation energy per atom/mae: 0.1293
# ### Evaluating on test.
# loss: 0.1169, formation energy per atom/mae: 0.1255
# epoch: 10.0023, loss: 0.1644, formation energy per atom/mae: 0.1765
# epoch: 10.2306, loss: 0.1634, formation energy per atom/mae: 0.1755
# epoch: 10.4589, loss: 0.1624, formation energy per atom/mae: 0.1744
# epoch: 10.6872, loss: 0.1615, formation energy per atom/mae: 0.1735
# epoch: 10.9155, loss: 0.1606, formation energy per atom/mae: 0.1724
# ### Evaluating on val.
# loss: 0.1138, formation energy per atom/mae: 0.1222
# ### Evaluating on test.
# loss: 0.1099, formation energy per atom/mae: 0.1180
# epoch: 11.0023, loss: 0.1602, formation energy per atom/mae: 0.1720
# epoch: 11.2306, loss: 0.1592, formation energy per atom/mae: 0.1710
# epoch: 11.4589, loss: 0.1584, formation energy per atom/mae: 0.1700
# epoch: 11.6872, loss: 0.1573, formation energy per atom/mae: 0.1689
# epoch: 11.9155, loss: 0.1563, formation energy per atom/mae: 0.1678
# ### Evaluating on val.
# loss: 0.0956, formation energy per atom/mae: 0.1026
# ### Evaluating on test.
# loss: 0.0892, formation energy per atom/mae: 0.0958
# epoch: 12.0023, loss: 0.1559, formation energy per atom/mae: 0.1674
# epoch: 12.2306, loss: 0.1551, formation energy per atom/mae: 0.1666
# epoch: 12.4589, loss: 0.1542, formation energy per atom/mae: 0.1656
# epoch: 12.6872, loss: 0.1533, formation energy per atom/mae: 0.1646
# epoch: 12.9155, loss: 0.1525, formation energy per atom/mae: 0.1637
# ### Evaluating on val.
# loss: 0.1377, formation energy per atom/mae: 0.1478
# ### Evaluating on test.
# loss: 0.1328, formation energy per atom/mae: 0.1426
# epoch: 13.0023, loss: 0.1522, formation energy per atom/mae: 0.1634
# epoch: 13.2306, loss: 0.1515, formation energy per atom/mae: 0.1627
# epoch: 13.4589, loss: 0.1509, formation energy per atom/mae: 0.1620
# epoch: 13.6872, loss: 0.1501, formation energy per atom/mae: 0.1611
# epoch: 13.9155, loss: 0.1493, formation energy per atom/mae: 0.1603
# ### Evaluating on val.
# loss: 0.0933, formation energy per atom/mae: 0.1002
# ### Evaluating on test.
# loss: 0.0885, formation energy per atom/mae: 0.0950
# epoch: 14.0023, loss: 0.1490, formation energy per atom/mae: 0.1600
# epoch: 14.2306, loss: 0.1484, formation energy per atom/mae: 0.1593
# epoch: 14.4589, loss: 0.1476, formation energy per atom/mae: 0.1584
# epoch: 14.6872, loss: 0.1467, formation energy per atom/mae: 0.1575
# epoch: 14.9155, loss: 0.1460, formation energy per atom/mae: 0.1567
# ### Evaluating on val.
# loss: 0.0870, formation energy per atom/mae: 0.0934
# ### Evaluating on test.
# loss: 0.0874, formation energy per atom/mae: 0.0939
# epoch: 15.0023, loss: 0.1457, formation energy per atom/mae: 0.1564
# epoch: 15.2306, loss: 0.1450, formation energy per atom/mae: 0.1557
# epoch: 15.4589, loss: 0.1442, formation energy per atom/mae: 0.1549
# epoch: 15.6872, loss: 0.1435, formation energy per atom/mae: 0.1541
# epoch: 15.9155, loss: 0.1429, formation energy per atom/mae: 0.1534
# ### Evaluating on val.
# loss: 0.0860, formation energy per atom/mae: 0.0923
# ### Evaluating on test.
# loss: 0.0862, formation energy per atom/mae: 0.0926
# epoch: 16.0023, loss: 0.1427, formation energy per atom/mae: 0.1532
# epoch: 16.2306, loss: 0.1420, formation energy per atom/mae: 0.1525
# epoch: 16.4589, loss: 0.1413, formation energy per atom/mae: 0.1518
# epoch: 16.6872, loss: 0.1406, formation energy per atom/mae: 0.1510
# epoch: 16.9155, loss: 0.1400, formation energy per atom/mae: 0.1503
# ### Evaluating on val.
# loss: 0.0888, formation energy per atom/mae: 0.0953
# ### Evaluating on test.
# loss: 0.0885, formation energy per atom/mae: 0.0950
# epoch: 17.0023, loss: 0.1398, formation energy per atom/mae: 0.1501
# epoch: 17.2306, loss: 0.1392, formation energy per atom/mae: 0.1494
# epoch: 17.4589, loss: 0.1386, formation energy per atom/mae: 0.1488
# epoch: 17.6872, loss: 0.1381, formation energy per atom/mae: 0.1483
# epoch: 17.9155, loss: 0.1375, formation energy per atom/mae: 0.1476
# ### Evaluating on val.
# loss: 0.0958, formation energy per atom/mae: 0.1029
# ### Evaluating on test.
# loss: 0.0946, formation energy per atom/mae: 0.1016
# epoch: 18.0023, loss: 0.1373, formation energy per atom/mae: 0.1474
# epoch: 18.2306, loss: 0.1367, formation energy per atom/mae: 0.1468
# epoch: 18.4589, loss: 0.1361, formation energy per atom/mae: 0.1461
# epoch: 18.6872, loss: 0.1355, formation energy per atom/mae: 0.1455
# epoch: 18.9155, loss: 0.1350, formation energy per atom/mae: 0.1449
# ### Evaluating on val.
# loss: 0.0852, formation energy per atom/mae: 0.0915
# ### Evaluating on test.
# loss: 0.0810, formation energy per atom/mae: 0.0870
# epoch: 19.0023, loss: 0.1347, formation energy per atom/mae: 0.1446
# epoch: 19.2306, loss: 0.1341, formation energy per atom/mae: 0.1440
# epoch: 19.4589, loss: 0.1335, formation energy per atom/mae: 0.1433
# epoch: 19.6872, loss: 0.1329, formation energy per atom/mae: 0.1427
# epoch: 19.9155, loss: 0.1324, formation energy per atom/mae: 0.1421
# ### Evaluating on val.
# loss: 0.0808, formation energy per atom/mae: 0.0868
# ### Evaluating on test.
# loss: 0.0784, formation energy per atom/mae: 0.0841
# epoch: 20.0023, loss: 0.1322, formation energy per atom/mae: 0.1419
# epoch: 20.2306, loss: 0.1316, formation energy per atom/mae: 0.1413
# epoch: 20.4589, loss: 0.1310, formation energy per atom/mae: 0.1407
# epoch: 20.6872, loss: 0.1305, formation energy per atom/mae: 0.1401
# epoch: 20.9155, loss: 0.1300, formation energy per atom/mae: 0.1396
# ### Evaluating on val.
# loss: 0.0942, formation energy per atom/mae: 0.1011
# ### Evaluating on test.
# loss: 0.0938, formation energy per atom/mae: 0.1007
# epoch: 21.0023, loss: 0.1298, formation energy per atom/mae: 0.1394
# epoch: 21.2306, loss: 0.1293, formation energy per atom/mae: 0.1389
# epoch: 21.4589, loss: 0.1288, formation energy per atom/mae: 0.1383
# epoch: 21.6872, loss: 0.1283, formation energy per atom/mae: 0.1378
# epoch: 21.9155, loss: 0.1278, formation energy per atom/mae: 0.1373
# ### Evaluating on val.
# loss: 0.0753, formation energy per atom/mae: 0.0808
# ### Evaluating on test.
# loss: 0.0764, formation energy per atom/mae: 0.0820
# epoch: 22.0023, loss: 0.1277, formation energy per atom/mae: 0.1371
# epoch: 22.2306, loss: 0.1273, formation energy per atom/mae: 0.1366
# epoch: 22.4589, loss: 0.1268, formation energy per atom/mae: 0.1361
# epoch: 22.6872, loss: 0.1264, formation energy per atom/mae: 0.1357
# epoch: 22.9155, loss: 0.1259, formation energy per atom/mae: 0.1352
# ### Evaluating on val.
# loss: 0.0903, formation energy per atom/mae: 0.0969
# ### Evaluating on test.
# loss: 0.0884, formation energy per atom/mae: 0.0949
# epoch: 23.0023, loss: 0.1258, formation energy per atom/mae: 0.1350
# epoch: 23.2306, loss: 0.1253, formation energy per atom/mae: 0.1346
# epoch: 23.4589, loss: 0.1249, formation energy per atom/mae: 0.1341
# epoch: 23.6872, loss: 0.1244, formation energy per atom/mae: 0.1336
# epoch: 23.9155, loss: 0.1240, formation energy per atom/mae: 0.1332
# ### Evaluating on val.
# loss: 0.0680, formation energy per atom/mae: 0.0730
# ### Evaluating on test.
# loss: 0.0710, formation energy per atom/mae: 0.0762
# epoch: 24.0023, loss: 0.1239, formation energy per atom/mae: 0.1330
# epoch: 24.2306, loss: 0.1235, formation energy per atom/mae: 0.1326
# epoch: 24.4589, loss: 0.1231, formation energy per atom/mae: 0.1322
# epoch: 24.6872, loss: 0.1227, formation energy per atom/mae: 0.1317
# epoch: 24.9155, loss: 0.1222, formation energy per atom/mae: 0.1312
# ### Evaluating on val.
# loss: 0.0785, formation energy per atom/mae: 0.0843
# ### Evaluating on test.
# loss: 0.0778, formation energy per atom/mae: 0.0836
# epoch: 25.0023, loss: 0.1221, formation energy per atom/mae: 0.1311
# epoch: 25.2306, loss: 0.1216, formation energy per atom/mae: 0.1306
# epoch: 25.4589, loss: 0.1212, formation energy per atom/mae: 0.1302
# epoch: 25.6872, loss: 0.1208, formation energy per atom/mae: 0.1297
# epoch: 25.9155, loss: 0.1204, formation energy per atom/mae: 0.1292
# ### Evaluating on val.
# loss: 0.0843, formation energy per atom/mae: 0.0905
# ### Evaluating on test.
# loss: 0.0821, formation energy per atom/mae: 0.0881
# epoch: 26.0023, loss: 0.1202, formation energy per atom/mae: 0.1291
# epoch: 26.2306, loss: 0.1198, formation energy per atom/mae: 0.1287
# epoch: 26.4589, loss: 0.1195, formation energy per atom/mae: 0.1283
# epoch: 26.6872, loss: 0.1190, formation energy per atom/mae: 0.1278
# epoch: 26.9155, loss: 0.1187, formation energy per atom/mae: 0.1274
# ### Evaluating on val.
# loss: 0.0693, formation energy per atom/mae: 0.0744
# ### Evaluating on test.
# loss: 0.0687, formation energy per atom/mae: 0.0738
# epoch: 27.0023, loss: 0.1186, formation energy per atom/mae: 0.1273
# epoch: 27.2306, loss: 0.1182, formation energy per atom/mae: 0.1269
# epoch: 27.4589, loss: 0.1178, formation energy per atom/mae: 0.1265
# epoch: 27.6872, loss: 0.1175, formation energy per atom/mae: 0.1261
# epoch: 27.9155, loss: 0.1171, formation energy per atom/mae: 0.1258
# ### Evaluating on val.
# loss: 0.0630, formation energy per atom/mae: 0.0677
# ### Evaluating on test.
# loss: 0.0625, formation energy per atom/mae: 0.0671
# epoch: 28.0023, loss: 0.1170, formation energy per atom/mae: 0.1256
# epoch: 28.2306, loss: 0.1166, formation energy per atom/mae: 0.1252
# epoch: 28.4589, loss: 0.1163, formation energy per atom/mae: 0.1249
# epoch: 28.6872, loss: 0.1160, formation energy per atom/mae: 0.1245
# epoch: 28.9155, loss: 0.1156, formation energy per atom/mae: 0.1242
# ### Evaluating on val.
# loss: 0.0665, formation energy per atom/mae: 0.0714
# ### Evaluating on test.
# loss: 0.0676, formation energy per atom/mae: 0.0725
# epoch: 29.0023, loss: 0.1155, formation energy per atom/mae: 0.1240
# epoch: 29.2306, loss: 0.1152, formation energy per atom/mae: 0.1236
# epoch: 29.4589, loss: 0.1148, formation energy per atom/mae: 0.1233
# epoch: 29.6872, loss: 0.1145, formation energy per atom/mae: 0.1229
# epoch: 29.9155, loss: 0.1141, formation energy per atom/mae: 0.1225
# ### Evaluating on val.
# loss: 0.0670, formation energy per atom/mae: 0.0719
# ### Evaluating on test.
# loss: 0.0661, formation energy per atom/mae: 0.0709
# epoch: 30.0023, loss: 0.1140, formation energy per atom/mae: 0.1224
# epoch: 30.2306, loss: 0.1137, formation energy per atom/mae: 0.1220
# epoch: 30.4589, loss: 0.1133, formation energy per atom/mae: 0.1217
# epoch: 30.6872, loss: 0.1131, formation energy per atom/mae: 0.1214
# epoch: 30.9155, loss: 0.1127, formation energy per atom/mae: 0.1210
# ### Evaluating on val.
# loss: 0.0770, formation energy per atom/mae: 0.0827
# ### Evaluating on test.
# loss: 0.0752, formation energy per atom/mae: 0.0807
# epoch: 31.0023, loss: 0.1126, formation energy per atom/mae: 0.1209
# epoch: 31.2306, loss: 0.1123, formation energy per atom/mae: 0.1206
# epoch: 31.4589, loss: 0.1120, formation energy per atom/mae: 0.1202
# epoch: 31.6872, loss: 0.1117, formation energy per atom/mae: 0.1199
# epoch: 31.9155, loss: 0.1114, formation energy per atom/mae: 0.1196
# ### Evaluating on val.
# loss: 0.0666, formation energy per atom/mae: 0.0715
# ### Evaluating on test.
# loss: 0.0656, formation energy per atom/mae: 0.0705
# epoch: 32.0023, loss: 0.1113, formation energy per atom/mae: 0.1195
# epoch: 32.2306, loss: 0.1110, formation energy per atom/mae: 0.1192
# epoch: 32.4589, loss: 0.1107, formation energy per atom/mae: 0.1189
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-3435b262f1ae> in <module>
# ----> 1 trainer.train()
#
# ~/projects/cgcnn/baselines/trainers/base_trainer.py in train(self)
#     243         for epoch in range(self.config["optim"]["max_epochs"]):
#     244             self.model.train()
# --> 245             for i, batch in enumerate(self.train_loader):
#     246                 batch = batch.to(self.device)
#     247
#
# /srv/share2/abhshkdz/local/anaconda3/envs/cgcnn/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     344     def __next__(self):
#     345         index = self._next_index()  # may raise StopIteration
# --> 346         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self._pin_memory:
#     348             data = _utils.pin_memory.pin_memory(data)
#
# /srv/share2/abhshkdz/local/anaconda3/envs/cgcnn/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
# ---> 47         return self.collate_fn(data)
#
# /srv/share2/abhshkdz/local/anaconda3/envs/cgcnn/lib/python3.6/site-packages/torch_geometric/data/dataloader.py in <lambda>(data_list)
#      30             shuffle,
#      31             collate_fn=lambda data_list: Batch.from_data_list(
# ---> 32                 data_list, follow_batch),
#      33             **kwargs)
#      34
#
# /srv/share2/abhshkdz/local/anaconda3/envs/cgcnn/lib/python3.6/site-packages/torch_geometric/data/batch.py in from_data_list(data_list, follow_batch)
#      49                     item = item + cumsum[key]
#      50                 if torch.is_tensor(item):
# ---> 51                     size = item.size(data.__cat_dim__(key, data[key]))
#      52                 else:
#      53                     size = 1
#
# /srv/share2/abhshkdz/local/anaconda3/envs/cgcnn/lib/python3.6/site-packages/torch_geometric/data/data.py in __cat_dim__(self, key, value)
#     139         # `*index*` and `*face*` should be concatenated in the last dimension,
#     140         # everything else in the first dimension.
# --> 141         return -1 if bool(re.search('(index|face)', key)) else 0
#     142
#     143     def __inc__(self, key, value):
#
# /srv/share2/abhshkdz/local/anaconda3/envs/cgcnn/lib/python3.6/re.py in search(pattern, string, flags)
#     180     """Scan through string looking for a match to the pattern, returning
#     181     a match object, or None if no match was found."""
# --> 182     return _compile(pattern, flags).search(string)
#     183
#     184 def sub(pattern, repl, string, count=0, flags=0):
#
# /srv/share2/abhshkdz/local/anaconda3/envs/cgcnn/lib/python3.6/re.py in _compile(pattern, flags)
#     287     # internal: compile pattern
#     288     try:
# --> 289         p, loc = _cache[type(pattern), pattern, flags]
#     290         if loc is None or loc == _locale.setlocale(_locale.LC_CTYPE):
#     291             return p
#
# KeyboardInterrupt:
